# %% [markdown]
# # 1. Import Library yang kita butuhkan
#
# - Pada perintah di bawah kami mengimport semua kebutuhan library yang kami butuhkan,
# - Jika temen temen tidak mau import semua library yang di butuhkan dalam step 1 temen temen cukup import library json saja untuk menghubungkan dataset yang sudah kita buat.
#
# ### Perlu di note sebelumnya di virtual environment kami sudah Install and import library yang di butuhkan seperti **tensorflow, keras, keras-models, pickle, nltk**
#
# Cara install:
#
# - pip install tensorflow
# - pip install keras
# - pip install keras-models
# - pip install pickle
# - pip install nltk

# %%
# import necessary libraries
import warnings
warnings.filterwarnings("ignore")
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
from keras.models import load_model

# create an object of WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# importing the GL Bot corpus file for pre-processing

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open("data.json").read()
intents = json.loads(data_file)

# %% [markdown]
# # 2. Data pre-processing

# %%
# preprocessing the json data
# tokenization
#nltk.download('punkt')
#nltk.download('wordnet')
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %% [markdown]
# ### Tokenisasi
#
# - Pada proses tokenisasi pada dasarnya adalah pemisahan kalimat, paragraf,
# atau seluruh dokumen teks menjadi unit yang lebih kecil, proses itu yang disebut token
#
# - Pada proses ini juga akan save documen tersebut menjadi file label.pkl dan texts.pkl (proses labeling)

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes", classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

# creating a pickle file to store the Python objects which we will use while predicting
pickle.dump(words,open('texts.pkl','wb')) 
pickle.dump(classes,open('labels.pkl','wb'))
# Out:
# 117 documents
# 115 classes ['greeting1', 'greeting10', 'greeting11', 'greeting12', 'greeting13', 'greeting14', 'greeting15', 'greeting16', 'greeting2', 'greeting3', 'greeting4', 'greeting5', 'greeting6', 'greeting7', 'greeting8', 'greeting9', 'greeting_malam', 'noanswer', 'pengalaman1', 'pengalaman2', 'pengalaman3', 'pengalaman4', 'pengalaman5', 'pengalaman6', 'pengalaman7', 'pengalaman8', 'pengalaman9', 'penutup1', 'penutup1a', 'penutup2', 'penutup3', 'penutup4', 'penutup5', 'skill1', 'skill10', 'skill11', 'skill12', 'skill13', 'skill14', 'skill15', 'skill16', 'skill17', 'skill18', 'skill19', 'skill2', 'skill20', 'skill21', 'skill22', 'skill23', 'skill24', 'skill25', 'skill26', 'skill27', 'skill28', 'skill29', 'skill3', 'skill30', 'skill31', 'skill32', 'skill33', 'skill34', 'skill35', 'skill36', 'skill37', 'skill38', 'skill39', 'skill4', 'skill40', 'skill41', 'skill42', 'skill43', 'skill44', 'skill45', 'skill46', 'skill47', 'skill48', 'skill49', 'skill5', 'skill50', 'skill51', 'skill52', 'skill53', 'skill54', 'skill55', 'skill56', 'skill57', 'skill58', 'skill59', 'skill6', 'skill60', 'skill61', 'skill62', 'skill63', 'skill7', 'skill8', 'skill9', 'tools1', 'tools10', 'tools11', 'tools12', 'tools13', 'tools14', 'tools15', 'tools16', 'tools17', 'tools18', 'tools19', 'tools2', 'tools3', 'tools4', 'tools5', 'tools6', 'tools7', 'tools8', 'tools9']
# 153 unique lemmatized words [',', 'adalah', 'algoritma', 'analisis', 'analysis', 'analyst', 'awan', 'bahasa', 'baik', 'baiklah', 'bayes', 'bekerja', 'boost', 'c', 'c++', 'cat', 'classification', 'cloud', 'clustering', 'code', 'coding', 'colab', 'computing', 'customer', 'data', 'database', 'decision', 'deep', 'disesuaikan', 'engineering', 'feature', 'forecasting', 'forest', 'gali', 'ggplot', 'google', 'gradien', 'hai', 'halo', 'hello', 'java', 'javascript', 'jt', 'jupyter', 'juta', 'k', 'k-means', 'karena', 'kasih', 'kelebihan', 'kelemahan', 'keputusan', 'kerja', 'ketahui', 'klasifikasi', 'klustering', 'knn', 'komputasi', 'kuasai', 'language', 'learning', 'library', 'machine', 'magang', 'malam', 'malem', 'manipulasi', 'manipulation', 'masalah', 'matplotlib', 'mean', 'melamar', 'membangun', 'membuat', 'menganalisis', 'mengerjakan', 'menggali', 'menyelesaikan', 'merapihkan', 'merupakan', 'mesin', 'minimum', 'mining', 'model', 'modeling', 'modelling', 'naive', 'nama', 'namaku', 'nearest', 'neighbor', 'network', 'neural', 'notebook', 'numpy', 'object', 'oop', 'oriented', 'pagi', 'panda', 'pembelajaran', 'pemodelan', 'pemrograman', 'perapihan', 'perkenalkan', 'permasalahan', 'pernah', 'php', 'pohon', 'prediksi', 'programmer', 'programming', 'project', 'proyek', 'pycharm', 'python', 'query', 'r', 'random', 'regresi', 'regression', 'rupiah', 'science', 'scientist', 'sebagai', 'selamat', 'selesai', 'service', 'siang', 'sore', 'sql', 'structured', 'studio', 'sublime', 'supervised', 'support', 'svm', 'teller', 'terima', 'text', 'transformasi', 'transformation', 'tree', 'unsupervised', 'upah', 'v', 'vector', 'visual', 'visualisasi', 'visualization', 'wrangling', 'xgboost', 'yaitu']

# %% [markdown]
# # 3. Creating Training Data
#
# - Pada dasarnya, bag of words adalah representasi sederhana dari setiap teks dalam sebuah kalimat sebagai bag of words-nya.

# %%
# create our training data
training = []

# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
   
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# shuffle features and converting it into numpy arrays
random.shuffle(training)
training = np.array(training)

# create train and test lists
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Training data created")
# Out:
# Training data created

# %% [markdown]
# # 5. Creating Modeling
#
# - Pada proses ini kami akan membuat model jaringan saraf dan menyimpan model tersebut

# %%
# Create NN model to predict the responses
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('models.h5', hist) # we will pickle this model to use in the future
print("\n")
print("*"*50)
print("\nModel Created Successfully!")
# Out:
# Epoch 1/200
# 24/24 [==============================] - 1s 2ms/step - loss: 4.7625 - accuracy: 0.0085
# Epoch 2/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.7521 - accuracy: 0.0000e+00
# Epoch 3/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.7386 - accuracy: 0.0000e+00
# Epoch 4/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.7391 - accuracy: 0.0000e+00
# Epoch 5/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.7157 - accuracy: 0.0171
# Epoch 6/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.6934 - accuracy: 0.0085
# Epoch 7/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.6947 - accuracy: 0.0256
# Epoch 8/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.6646 - accuracy: 0.0427
# Epoch 9/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.6777 - accuracy: 0.0085
# Epoch 10/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.6417 - accuracy: 0.0171
# Epoch 11/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.6510 - accuracy: 0.0171
# Epoch 12/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.6073 - accuracy: 0.0256
# Epoch 13/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.5838 - accuracy: 0.0342
# Epoch 14/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.5414 - accuracy: 0.0855
# Epoch 15/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.5460 - accuracy: 0.0684
# Epoch 16/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.4804 - accuracy: 0.0855
# Epoch 17/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.4462 - accuracy: 0.0940
# Epoch 18/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.4512 - accuracy: 0.0684
# Epoch 19/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.3822 - accuracy: 0.0940
# Epoch 20/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.2837 - accuracy: 0.1026
# Epoch 21/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.2914 - accuracy: 0.1026
# Epoch 22/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.2471 - accuracy: 0.1111
# Epoch 23/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.2029 - accuracy: 0.1368
# Epoch 24/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.1377 - accuracy: 0.1282
# Epoch 25/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.0445 - accuracy: 0.1368
# Epoch 26/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.9719 - accuracy: 0.1453
# Epoch 27/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.9200 - accuracy: 0.1282
# Epoch 28/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.8719 - accuracy: 0.1538
# Epoch 29/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.8746 - accuracy: 0.1880
# Epoch 30/200
# 24/24 [==============================] - 0s 1ms/step - loss: 3.6468 - accuracy: 0.2051
# Epoch 31/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.6133 - accuracy: 0.1453
# Epoch 32/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.4127 - accuracy: 0.2137
# Epoch 33/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.4717 - accuracy: 0.2308
# Epoch 34/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.4412 - accuracy: 0.2393
# Epoch 35/200
# 24/24 [==============================] - 0s 3ms/step - loss: 3.3547 - accuracy: 0.2650
# Epoch 36/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.2278 - accuracy: 0.2564
# Epoch 37/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.0310 - accuracy: 0.2906
# Epoch 38/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.1758 - accuracy: 0.2051
# Epoch 39/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.0518 - accuracy: 0.2735
# Epoch 40/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.1425 - accuracy: 0.2650
# Epoch 41/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.7241 - accuracy: 0.3590
# Epoch 42/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.7914 - accuracy: 0.2906
# Epoch 43/200
# 24/24 [==============================] - 0s 1ms/step - loss: 2.8199 - accuracy: 0.2991
# Epoch 44/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.5555 - accuracy: 0.3846
# Epoch 45/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.6813 - accuracy: 0.3162
# Epoch 46/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.4492 - accuracy: 0.3590
# Epoch 47/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.5777 - accuracy: 0.3504
# Epoch 48/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.4153 - accuracy: 0.3419
# Epoch 49/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.3490 - accuracy: 0.3761
# Epoch 50/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.4088 - accuracy: 0.4017
# Epoch 51/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.3080 - accuracy: 0.4274
# Epoch 52/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.1596 - accuracy: 0.4530
# Epoch 53/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.0880 - accuracy: 0.4274
# Epoch 54/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.1284 - accuracy: 0.4615
# Epoch 55/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.1157 - accuracy: 0.4701
# Epoch 56/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.7671 - accuracy: 0.5470
# Epoch 57/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.0002 - accuracy: 0.5641
# Epoch 58/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.9165 - accuracy: 0.4957
# Epoch 59/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.0465 - accuracy: 0.4615
# Epoch 60/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.9094 - accuracy: 0.4615
# Epoch 61/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.8701 - accuracy: 0.5299
# Epoch 62/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.7291 - accuracy: 0.5726
# Epoch 63/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.6255 - accuracy: 0.5556
# Epoch 64/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.6664 - accuracy: 0.6068
# Epoch 65/200
# 24/24 [==============================] - 0s 1ms/step - loss: 1.5776 - accuracy: 0.5897
# Epoch 66/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.7671 - accuracy: 0.5556
# Epoch 67/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.6485 - accuracy: 0.5812
# Epoch 68/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.5856 - accuracy: 0.5983
# Epoch 69/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.6121 - accuracy: 0.5983
# Epoch 70/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.4761 - accuracy: 0.5897
# Epoch 71/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.5130 - accuracy: 0.6239
# Epoch 72/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.6146 - accuracy: 0.5726
# Epoch 73/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3823 - accuracy: 0.6325
# Epoch 74/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0950 - accuracy: 0.7692
# Epoch 75/200
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2824 - accuracy: 0.7009
# Epoch 76/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2637 - accuracy: 0.6239
# Epoch 77/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3084 - accuracy: 0.6239
# Epoch 78/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.5614 - accuracy: 0.5641
# Epoch 79/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3819 - accuracy: 0.6496
# Epoch 80/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.4289 - accuracy: 0.6581
# Epoch 81/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1912 - accuracy: 0.6752
# Epoch 82/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.3772 - accuracy: 0.6752
# Epoch 83/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2831 - accuracy: 0.6667
# Epoch 84/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3401 - accuracy: 0.6239
# Epoch 85/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3031 - accuracy: 0.6923
# Epoch 86/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2000 - accuracy: 0.6325
# Epoch 87/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1828 - accuracy: 0.6923
# Epoch 88/200
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2487 - accuracy: 0.6154
# Epoch 89/200
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0064 - accuracy: 0.7009
# Epoch 90/200
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0058 - accuracy: 0.7094
# Epoch 91/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0198 - accuracy: 0.6923
# Epoch 92/200
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1183 - accuracy: 0.6838
# Epoch 93/200
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0844 - accuracy: 0.6838
# Epoch 94/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8592 - accuracy: 0.7607
# Epoch 95/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9985 - accuracy: 0.7350
# Epoch 96/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8222 - accuracy: 0.7607
# Epoch 97/200
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2634 - accuracy: 0.6581
# Epoch 98/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9283 - accuracy: 0.7350
# Epoch 99/200
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0633 - accuracy: 0.7009
# Epoch 100/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8355 - accuracy: 0.7949
# Epoch 101/200
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0457 - accuracy: 0.6496
# Epoch 102/200
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1593 - accuracy: 0.7094
# Epoch 103/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0279 - accuracy: 0.6581
# Epoch 104/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0792 - accuracy: 0.6923
# Epoch 105/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8994 - accuracy: 0.7863
# Epoch 106/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9091 - accuracy: 0.7094
# Epoch 107/200
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0199 - accuracy: 0.7778
# Epoch 108/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8174 - accuracy: 0.7607
# Epoch 109/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9260 - accuracy: 0.7436
# Epoch 110/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7539 - accuracy: 0.8120
# Epoch 111/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8297 - accuracy: 0.7778
# Epoch 112/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9698 - accuracy: 0.7265
# Epoch 113/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8110 - accuracy: 0.7607
# Epoch 114/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9010 - accuracy: 0.7265
# Epoch 115/200
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0157 - accuracy: 0.7265
# Epoch 116/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9035 - accuracy: 0.7436
# Epoch 117/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9027 - accuracy: 0.7265
# Epoch 118/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7750 - accuracy: 0.7863
# Epoch 119/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6566 - accuracy: 0.8462
# Epoch 120/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8063 - accuracy: 0.7778
# Epoch 121/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8870 - accuracy: 0.7692
# Epoch 122/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8383 - accuracy: 0.7436
# Epoch 123/200
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0160 - accuracy: 0.6838
# Epoch 124/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9001 - accuracy: 0.7436
# Epoch 125/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8594 - accuracy: 0.7094
# Epoch 126/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7390 - accuracy: 0.7692
# Epoch 127/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5702 - accuracy: 0.8291
# Epoch 128/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8809 - accuracy: 0.7350
# Epoch 129/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7167 - accuracy: 0.7778
# Epoch 130/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7663 - accuracy: 0.7778
# Epoch 131/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9990 - accuracy: 0.6667
# Epoch 132/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8720 - accuracy: 0.7521
# Epoch 133/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8993 - accuracy: 0.7265
# Epoch 134/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9307 - accuracy: 0.7436
# Epoch 135/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8975 - accuracy: 0.6752
# Epoch 136/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8037 - accuracy: 0.7521
# Epoch 137/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5932 - accuracy: 0.8376
# Epoch 138/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5381 - accuracy: 0.8291
# Epoch 139/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8310 - accuracy: 0.7436
# Epoch 140/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4573 - accuracy: 0.8803
# Epoch 141/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7168 - accuracy: 0.7778
# Epoch 142/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7024 - accuracy: 0.7692
# Epoch 143/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7237 - accuracy: 0.7949
# Epoch 144/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5690 - accuracy: 0.8205
# Epoch 145/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7386 - accuracy: 0.7863
# Epoch 146/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6416 - accuracy: 0.8034
# Epoch 147/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7213 - accuracy: 0.8205
# Epoch 148/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7475 - accuracy: 0.7949
# Epoch 149/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6722 - accuracy: 0.7863
# Epoch 150/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8239 - accuracy: 0.7094
# Epoch 151/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6270 - accuracy: 0.7949
# Epoch 152/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7320 - accuracy: 0.7949
# Epoch 153/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7082 - accuracy: 0.7778
# Epoch 154/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6335 - accuracy: 0.8034
# Epoch 155/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6281 - accuracy: 0.8205
# Epoch 156/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7324 - accuracy: 0.8034
# Epoch 157/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7181 - accuracy: 0.7863
# Epoch 158/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7794 - accuracy: 0.7436
# Epoch 159/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7740 - accuracy: 0.7778
# Epoch 160/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6863 - accuracy: 0.7778
# Epoch 161/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8670 - accuracy: 0.7778
# Epoch 162/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7024 - accuracy: 0.7607
# Epoch 163/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7100 - accuracy: 0.7778
# Epoch 164/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5724 - accuracy: 0.7863
# Epoch 165/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5782 - accuracy: 0.8205
# Epoch 166/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7064 - accuracy: 0.7692
# Epoch 167/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6596 - accuracy: 0.7863
# Epoch 168/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6446 - accuracy: 0.7863
# Epoch 169/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5210 - accuracy: 0.8376
# Epoch 170/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6538 - accuracy: 0.8205
# Epoch 171/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8050 - accuracy: 0.7692
# Epoch 172/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6529 - accuracy: 0.8205
# Epoch 173/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6724 - accuracy: 0.8120
# Epoch 174/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5808 - accuracy: 0.8205
# Epoch 175/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7183 - accuracy: 0.7778
# Epoch 176/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6508 - accuracy: 0.8205
# Epoch 177/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7156 - accuracy: 0.8034
# Epoch 178/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5307 - accuracy: 0.8120
# Epoch 179/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8940 - accuracy: 0.7350
# Epoch 180/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6159 - accuracy: 0.8291
# Epoch 181/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5244 - accuracy: 0.8718
# Epoch 182/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5682 - accuracy: 0.8120
# Epoch 183/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6496 - accuracy: 0.7692
# Epoch 184/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6342 - accuracy: 0.7949
# Epoch 185/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6989 - accuracy: 0.7949
# Epoch 186/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5159 - accuracy: 0.8547
# Epoch 187/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4186 - accuracy: 0.8718
# Epoch 188/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6700 - accuracy: 0.8205
# Epoch 189/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5379 - accuracy: 0.8291
# Epoch 190/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5462 - accuracy: 0.8547
# Epoch 191/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5777 - accuracy: 0.8376
# Epoch 192/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7462 - accuracy: 0.7863
# Epoch 193/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7458 - accuracy: 0.8376
# Epoch 194/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5878 - accuracy: 0.8291
# Epoch 195/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6279 - accuracy: 0.8120
# Epoch 196/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5844 - accuracy: 0.8205
# Epoch 197/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5996 - accuracy: 0.8120
# Epoch 198/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5702 - accuracy: 0.8462
# Epoch 199/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4998 - accuracy: 0.8547
# Epoch 200/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6089 - accuracy: 0.8034
#
#
# **************************************************
#
# Model Created Successfully!
